# %%
import pandas as pd

print(pd.__version__)
# Out:
# 3.0.2

# %%
import pandas as pd

data = [100, 102, 104]

# series = pd.Series(data)

# series = pd.Series(data, index=["a", "b", "c"])

series = pd.Series(data, index=["No 1", "No 2", "No 3"])

print(series)
# Out:
# No 1    100
# No 2    102
# No 3    104
# dtype: int64

# %%
import pandas as pd

data = [100, 102, 104]

series = pd.Series(data, index=["a", "b", "c"])

print(series.loc["b"])
# Out:
# 102

# %%
import pandas as pd

data = [100, 102, 104]

series = pd.Series(data, index=["a", "b", "c"])

series.loc["b"] = 200

print(series)
# Out:
# a    100
# b    200
# c    104
# dtype: int64

# %%
import pandas as pd

data = [100, 102, 104]

series = pd.Series(data, index=["a", "b", "c"])

print(series.iloc[0])
print(series.iloc[1])
print(series.iloc[2])
# Out:
# 100
# 102
# 104

# %%
import pandas as pd

data = [100, 102, 104, 200, 210]

series = pd.Series(data, index=["a", "b", "c", "d", "e"])

print(series[series > 190])
# Out:
# d    200
# e    210
# dtype: int64

# %%
import pandas as pd

calories = {"Day 1" : 1250, "Day 2" : 2300, "Day 3" : 1730}

series = pd.Series(calories)

print(series)
# Out:
# Day 1    1250
# Day 2    2300
# Day 3    1730
# dtype: int64

# %%
import pandas as pd

calories = {"Day 1" : 1250, "Day 2" : 2300, "Day 3" : 1730}

series = pd.Series(calories)

print(series[series > 2000])
print(series[series < 2000])
# Out:
# Day 2    2300
# dtype: int64
# Day 1    1250
# Day 3    1730
# dtype: int64

# %%
import pandas as pd

data = {
    "Name" : ["Sam", "Jhon", "Bob"],
    "Age" : [20, 65, 37]
}

df = pd.DataFrame(data)

print(df)
# Out:
#    Name  Age
# 0   Sam   20
# 1  Jhon   65
# 2   Bob   37

# %%
import pandas as pd

data = {
    "Name" : ["Sam", "Jhon", "Bob"],
    "Age" : [20, 65, 37]
}

df = pd.DataFrame(data, index=["Person 1", "Person 2", "Person 3"])

print(df)

print(df.loc["Person 2"])

print(df.iloc[2])
# Out:
#           Name  Age
# Person 1   Sam   20
# Person 2  Jhon   65
# Person 3   Bob   37
# Name    Jhon
# Age       65
# Name: Person 2, dtype: object
# Name    Bob
# Age      37
# Name: Person 3, dtype: object

# %%
import pandas as pd

data = {
    "Name" : ["Sam", "Jhon", "Bob"],
    "Age" : [20, 65, 37]
}

df = pd.DataFrame(data, index=["Person 1", "Person 2", "Person 3"])

# Add new column
df["Job"] = ["SE", "QA", "N/A"]

# Add new row
new_row = pd.DataFrame([{"Name" : "Kamal", "Age" : 45, "Job" : "AI"}])
df = pd.concat([df, new_row])

print(df)
# Out:
#            Name  Age  Job
# Person 1    Sam   20   SE
# Person 2   Jhon   65   QA
# Person 3    Bob   37  N/A
# 0         Kamal   45   AI

# %%
import pandas as pd

data = {
    "Name" : ["Sam", "Jhon", "Bob"],
    "Age" : [20, 65, 37]
}

df = pd.DataFrame(data, index=["Person 1", "Person 2", "Person 3"])

# Add new column
df["Job"] = ["SE", "QA", "N/A"]

# Add new row
new_row = pd.DataFrame([{"Name" : "Kamal", "Age" : 45, "Job" : "AI"}], index=["Person 4"])
df = pd.concat([df, new_row])

print(df)
# Out:
#            Name  Age  Job
# Person 1    Sam   20   SE
# Person 2   Jhon   65   QA
# Person 3    Bob   37  N/A
# Person 4  Kamal   45   AI

# %%
import pandas as pd

data = {
    "Name" : ["Sam", "Jhon", "Bob"],
    "Age" : [20, 65, 37]
}

df = pd.DataFrame(data, index=["Person 1", "Person 2", "Person 3"])

# Add new column
df["Job"] = ["SE", "QA", "N/A"]

# Add new rows
new_rows = pd.DataFrame([{"Name" : "Kamal", "Age" : 45, "Job" : "AI"},
                         {"Name" : "Sandy", "Age" : 27, "Job" : "DB"}], 
                         index=["Person 4", "Person 5"])
df = pd.concat([df, new_rows])

print(df)
# Out:
#            Name  Age  Job
# Person 1    Sam   20   SE
# Person 2   Jhon   65   QA
# Person 3    Bob   37  N/A
# Person 4  Kamal   45   AI
# Person 5  Sandy   27   DB

# %%
import pandas as pd

df = pd.read_csv("data.csv")

print(df)
# Out:
#    Employee_ID        Name Department  Age  Salary   Join_Date  \
# 0          101       Anura      Sales   32   55000  2021-03-15
# 1          102       Nimal         IT   28   72000  2022-01-10
# 2          103       Kamal         HR   45   65000  2019-08-22
# 3          104       Ruwan         IT   35   85000  2020-11-05
# 4          105    Priyanka  Marketing   24   42000  2023-05-18
# 5          106       Sunil      Sales   40   58000  2018-02-14
# 6          107      Dilini         HR   29   48000  2022-07-01
# 7          108  Sucharitha         IT   31   90000  2021-10-12
# 8          109       Kasun  Marketing   38   53000  2020-04-30
# 9          110    Chathuri      Sales   26   46000  2023-02-25
#
#   Performance_Rating
# 0                  A
# 1                  B
# 2                  A
# 3                  A
# 4                  C
# 5                  B
# 6                  B
# 7                  A
# 8                  C
# 9                  B

# %%
import pandas as pd

df = pd.read_csv("data.csv")

print(df.to_string())
# Out:
#    Employee_ID        Name Department  Age  Salary   Join_Date Performance_Rating
# 0          101       Anura      Sales   32   55000  2021-03-15                  A
# 1          102       Nimal         IT   28   72000  2022-01-10                  B
# 2          103       Kamal         HR   45   65000  2019-08-22                  A
# 3          104       Ruwan         IT   35   85000  2020-11-05                  A
# 4          105    Priyanka  Marketing   24   42000  2023-05-18                  C
# 5          106       Sunil      Sales   40   58000  2018-02-14                  B
# 6          107      Dilini         HR   29   48000  2022-07-01                  B
# 7          108  Sucharitha         IT   31   90000  2021-10-12                  A
# 8          109       Kasun  Marketing   38   53000  2020-04-30                  C
# 9          110    Chathuri      Sales   26   46000  2023-02-25                  B

# %%
import pandas as pd

df = pd.read_json("data.json")

print(df.to_string())
# Out:
#    Employee_ID      Name Department  Age  Salary Performance_Rating
# 0          101     Anura      Sales   32   55000                  A
# 1          102     Nimal         IT   28   72000                  B
# 2          103     Kamal         HR   45   65000                  A
# 3          104     Ruwan         IT   35   85000                  A
# 4          105  Priyanka  Marketing   24   42000                  C

# %%
import pandas as pd

df = pd.read_csv("data.csv")

# Selection by column
print(df["Name"])

# print(df["Name"].to_string)
# Out:
# 0         Anura
# 1         Nimal
# 2         Kamal
# 3         Ruwan
# 4      Priyanka
# 5         Sunil
# 6        Dilini
# 7    Sucharitha
# 8         Kasun
# 9      Chathuri
# Name: Name, dtype: str

# %%
import pandas as pd

df = pd.read_csv("data.csv")

# Selection by columns
print(df[["Name", "Age", "Salary"]])
# Out:
#          Name  Age  Salary
# 0       Anura   32   55000
# 1       Nimal   28   72000
# 2       Kamal   45   65000
# 3       Ruwan   35   85000
# 4    Priyanka   24   42000
# 5       Sunil   40   58000
# 6      Dilini   29   48000
# 7  Sucharitha   31   90000
# 8       Kasun   38   53000
# 9    Chathuri   26   46000

# %%
import pandas as pd

df = pd.read_csv("data.csv")

# Select by row
print(df.loc[1])
# Out:
# Employee_ID                  102
# Name                       Nimal
# Department                    IT
# Age                           28
# Salary                     72000
# Join_Date             2022-01-10
# Performance_Rating             B
# Name: 1, dtype: object

# %%
import pandas as pd

df = pd.read_csv("data.csv", index_col="Name")

print(df)
# Out:
#             Employee_ID Department  Age  Salary   Join_Date Performance_Rating
# Name
# Anura               101      Sales   32   55000  2021-03-15                  A
# Nimal               102         IT   28   72000  2022-01-10                  B
# Kamal               103         HR   45   65000  2019-08-22                  A
# Ruwan               104         IT   35   85000  2020-11-05                  A
# Priyanka            105  Marketing   24   42000  2023-05-18                  C
# Sunil               106      Sales   40   58000  2018-02-14                  B
# Dilini              107         HR   29   48000  2022-07-01                  B
# Sucharitha          108         IT   31   90000  2021-10-12                  A
# Kasun               109  Marketing   38   53000  2020-04-30                  C
# Chathuri            110      Sales   26   46000  2023-02-25                  B

# %%
import pandas as pd

df = pd.read_csv("data.csv", index_col="Name")

print(df.loc["Kamal"])
# Out:
# Employee_ID                  103
# Department                    HR
# Age                           45
# Salary                     65000
# Join_Date             2019-08-22
# Performance_Rating             A
# Name: Kamal, dtype: object

# %%
import pandas as pd

df = pd.read_csv("data.csv", index_col="Name")

print(df.loc["Chathuri", ["Age", "Salary"]])
# Out:
# Age          26
# Salary    46000
# Name: Chathuri, dtype: int64

# %%
import pandas as pd

df = pd.read_csv("data.csv")

# Selection by rows
print(df.iloc[0:4])
# Out:
#    Employee_ID   Name Department  Age  Salary   Join_Date Performance_Rating
# 0          101  Anura      Sales   32   55000  2021-03-15                  A
# 1          102  Nimal         IT   28   72000  2022-01-10                  B
# 2          103  Kamal         HR   45   65000  2019-08-22                  A
# 3          104  Ruwan         IT   35   85000  2020-11-05                  A

# %%
import pandas as pd

df = pd.read_csv("data.csv")

# Selection by rows
print(df.iloc[0:4, 0:6])
# Out:
#    Employee_ID   Name Department  Age  Salary   Join_Date
# 0          101  Anura      Sales   32   55000  2021-03-15
# 1          102  Nimal         IT   28   72000  2022-01-10
# 2          103  Kamal         HR   45   65000  2019-08-22
# 3          104  Ruwan         IT   35   85000  2020-11-05
